# %% [markdown]
# # Introduction to SQL
#
# # 1. What Is SQL?
#
# SQL (Structured Query Language) is the standard language used to communicate with relational databases.
#
# It allows you to:
# - Retrieve data
# - Filter data
# - Join tables
# - Aggregate information
# - Update or delete records
#
# SQL is commonly used alongside:
# - Excel (data extraction before analysis)
# - Power BI (data preparation before visualization)
# - Python (data querying inside scripts)

# %%
# gap

# %% [markdown]
# # 2. What Is a Database?
#
# A database is an organized collection of structured data stored electronically.
#
# A DBMS (Database Management System) is the software that:
# - Stores data
# - Manages access
# - Processes queries
# - Returns results
#
# Examples of SQL database systems:
# - SQLite (lightweight, file-based)
# - MySQL (server-based)
# - PostgreSQL (enterprise-grade)

# %%
# gap

# %% [markdown]
# # 3. Types of Databases
#
# | Type | Description | Example Use |
# |------|------------|-------------|
# | Relational | Tables (rows & columns) | Most business systems |
# | NoSQL | Flexible data models | Big data, real-time apps |
# | In-Memory | Stored in RAM | High-speed systems |
# | Distributed | Across multiple locations | Cloud systems |
# | Hierarchical | Tree-like structure | Legacy systems |
#
# This course focuses on relational databases.

# %%
# gap

# %% [markdown]
# # 4. Relational Database Fundamentals
#
# ## Tables
# Store data in rows and columns.
#
# Example:
#
# | id | name | age | email |
# |----|------|-----|-------|
#
#
# ## Rows (Records)
# Each row represents one entity instance.
#
# Example:
# One row equals one customer.
#
# ## Columns (Fields)
# Each column represents an attribute.
#
# Example:
# CustomerID, Name, Email.
#
# ## Primary Key (PK)
#
# - Unique identifier for each record
# - No duplicates allowed
# - Usually ends with “ID” or “Number”
#
# Example:
# customerID
#
# ## Foreign Key (FK)
#
# - A column that links to a primary key in another table
# - Creates relationships between tables
#
# Example:
# customerID inside Orders table

# %%
# gap

# %% [markdown]
# # 5. Table Relationships
#
# | Type | Description | Example |
# |-------|------------|----------|
# | One-to-One | 1 record linked to 1 record | Person to Passport |
# | One-to-Many | 1 record linked to many records | Customer to Orders |
# | Many-to-Many | Many linked to many | Students to Courses |
#
# Relationships are built using primary keys and foreign keys.
#
#
# # 6. SQL Database Structure
#
# An SQL database:
# - Contains multiple tables
# - Enforces column data types
# - Supports relationships
# - Stores schema (structure)
#
# Example table schema:
#
# ```sql
# CREATE TABLE people (
#   id INTEGER PRIMARY KEY,
#   name TEXT,
#   age INTEGER,
#   email TEXT
# );

# %%
# installations
# !pip install -U ipython-sql prettytable

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ## Connecting to a SQLite Database in Google Colab

# %% [markdown]
# ```pyhton
# %sql sqlite:///<path_to_your_database>
# ```

# %%
# %sql sqlite:///data.sqlite

# %%
# %%sql
# select * from payments limit 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('103', 'HQ336336', '2004-10-19', '6066.78'),
#  ('103', 'JM555205', '2003-06-05', '14571.44'),
#  ('103', 'OM314933', '2004-12-18', '1676.14'),
#  ('112', 'BO864823', '2004-12-17', '14191.12'),
#  ('112', 'HQ55022', '2003-06-06', '32641.98')]

# %%
# %%sql
# SELECT * FROM offices;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('1', 'San Francisco', '+1 650 219 4782', '100 Market Street', 'Suite 300', 'CA', 'USA', '94080', 'NA'),
#  ('2', 'Boston', '+1 215 837 0825', '1550 Court Place', 'Suite 102', 'MA', 'USA', '02107', 'NA'),
#  ('3', 'NYC', '+1 212 555 3000', '523 East 53rd Street', 'apt. 5A', 'NY', 'USA', '10022', 'NA'),
#  ('4', 'Paris', '+33 14 723 4404', "43 Rue Jouffroy D'abbans", '', '', 'France', '75017', 'EMEA'),
#  ('5', 'Tokyo', '+81 33 224 5000', '4-1 Kioicho', '', 'Chiyoda-Ku', 'Japan', '102-8578', 'Japan'),
#  ('6', 'Sydney', '+61 2 9264 2451', '5-11 Wentworth Avenue', 'Floor #2', '', 'Australia', 'NSW 2010', 'APAC'),
#  ('7', 'London', '+44 20 7877 2041', '25 Old Broad Street', 'Level 7', '', 'UK', 'EC2N 1HN', 'EMEA')]

# %% [markdown]
# To view the column names of the offices table in your SQLite database, you can use the following SQL query:
#
#
# ```Sql
# %%sql
# PRAGMA table_info(offices);
# ```
# **Explanation:**
#
# `PRAGMA table_info(offices)`: This is a special SQLite command that provides information about the structure of the office table, including column names, data types, and other metadata like whether a column is part of the primary key or allows NULL values.
#
# > Note: This is a handy way to inspect the structure of a table and view its column names.

# %%
# %%sql
# PRAGMA table_info(offices);
# Out:
#  * sqlite:///data.sqlite
# Done.
# [(0, 'officeCode', '', 0, None, 0),
#  (1, 'city', '', 0, None, 0),
#  (2, 'phone', '', 0, None, 0),
#  (3, 'addressLine1', '', 0, None, 0),
#  (4, 'addressLine2', '', 0, None, 0),
#  (5, 'state', '', 0, None, 0),
#  (6, 'country', '', 0, None, 0),
#  (7, 'postalCode', '', 0, None, 0),
#  (8, 'territory', '', 0, None, 0)]

# %%
# %%sql
# PRAGMA table_info(payments)
# Out:
#  * sqlite:///data.sqlite
# Done.
# [(0, 'customerNumber', '', 0, None, 0),
#  (1, 'checkNumber', '', 0, None, 0),
#  (2, 'paymentDate', '', 0, None, 0),
#  (3, 'amount', '', 0, None, 0)]

# %% [markdown]
# # Using SELECT to Subset and Transform Data
#
# # Introduction
#
# This lesson introduces how to use `SELECT` to:
#
# - Subset columns from a database table
# - Create column aliases
# - Transform data using `CASE` statements

# %% [markdown]
# ## Retrieving All Information from a Table
#
# We will start with the employees table.
# ```sql
# %%sql
# SELECT *
# FROM employees;
# ```

# %%
# %%sql
# SELECT *
# FROM employees
# LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('1002', 'Murphy', 'Diane', 'x5800', 'dmurphy@classicmodelcars.com', '1', '', 'President'),
#  ('1056', 'Patterson', 'Mary', 'x4611', 'mpatterso@classicmodelcars.com', '1', '1002', 'VP Sales'),
#  ('1076', 'Firrelli', 'Jeff', 'x9273', 'jfirrelli@classicmodelcars.com', '1', '1002', 'VP Marketing'),
#  ('1088', 'Patterson', 'William', 'x4871', 'wpatterson@classicmodelcars.com', '6', '1056', 'Sales Manager (APAC)'),
#  ('1102', 'Bondur', 'Gerard', 'x5408', 'gbondur@classicmodelcars.com', '4', '1056', 'Sale Manager (EMEA)')]

# %%
# %%sql
# SELECT *
# FROM payments
# LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('103', 'HQ336336', '2004-10-19', '6066.78'),
#  ('103', 'JM555205', '2003-06-05', '14571.44'),
#  ('103', 'OM314933', '2004-12-18', '1676.14'),
#  ('112', 'BO864823', '2004-12-17', '14191.12'),
#  ('112', 'HQ55022', '2003-06-06', '32641.98')]

# %%
# %%sql
# SELECT *
# FROM products
# LIMIT 3
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('S10_1678', '1969 Harley Davidson Ultimate Chopper', 'Motorcycles', '1:10', 'Min Lin Diecast', 'This replica features working kickstand, front suspension, gear-shift lever, footbrake lever, drive chain, wheels and steering. All parts are particularly delicate due to their precise scale and require special care and attention.', '7933', '48.81', '95.70'),
#  ('S10_1949', '1952 Alpine Renault 1300', 'Classic Cars', '1:10', 'Classic Metal Creations', 'Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.', '7305', '98.58', '214.30'),
# ...

# %% [markdown]
# **Breakdown**
#
# `%%sql → Tells the notebook this cell contains SQL`
#
# `SELECT * → Selects all columns`
#
# `FROM employees → Specifies the table`

# %% [markdown]
# ## Retrieving a Subset of Columns
#
# Instead of *, specify column names separated by commas

# %%
# %%sql
# SELECT lastName, firstName
# FROM employees
# LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('Murphy', 'Diane'),
#  ('Patterson', 'Mary'),
#  ('Firrelli', 'Jeff'),
#  ('Patterson', 'William'),
#  ('Bondur', 'Gerard')]

# %%
# %%sql
# PRAGMA table_info(products)
# Out:
#  * sqlite:///data.sqlite
# Done.
# [(0, 'productCode', '', 0, None, 0),
#  (1, 'productName', '', 0, None, 0),
#  (2, 'productLine', '', 0, None, 0),
#  (3, 'productScale', '', 0, None, 0),
#  (4, 'productVendor', '', 0, None, 0),
#  (5, 'productDescription', '', 0, None, 0),
#  (6, 'quantityInStock', '', 0, None, 0),
#  (7, 'buyPrice', '', 0, None, 0),
#  (8, 'MSRP', '', 0, None, 0)]

# %%
# %%sql
# SELECT productName,MSRP
# FROM products
# LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('1969 Harley Davidson Ultimate Chopper', '95.70'),
#  ('1952 Alpine Renault 1300', '214.30'),
#  ('1996 Moto Guzzi 1100i', '118.94'),
#  ('2003 Harley-Davidson Eagle Drag Bike', '193.66'),
#  ('1972 Alfa Romeo GTA', '136.00')]

# %% [markdown]
# ## Using Aliases (AS)
#
# Aliases rename columns in the output

# %%
# %%sql
# SELECT firstName AS name
# FROM employees
# LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('Diane',), ('Mary',), ('Jeff',), ('William',), ('Gerard',)]

# %%
# %%sql
# SELECT productName as name ,MSRP AS retail_price
# FROM products
# LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('1969 Harley Davidson Ultimate Chopper', '95.70'),
#  ('1952 Alpine Renault 1300', '214.30'),
#  ('1996 Moto Guzzi 1100i', '118.94'),
#  ('2003 Harley-Davidson Eagle Drag Bike', '193.66'),
#  ('1972 Alfa Romeo GTA', '136.00')]

# %% [markdown]
# AS name → Renames firstName to name in the result

# %% [markdown]
# ## Using SQL CASE Statements
#
# The CASE statement allows conditional logic inside SQL queries.
#
# Basic Structure
# Simple CASE
# ``` sql
# CASE expression
#     WHEN value1 THEN result1
#     WHEN value2 THEN result2
#     ELSE default_result
# END
# ```

# %%
# %%sql
# SELECT firstName, lastName, jobTitle,
#        CASE
#            WHEN jobTitle = "Sales Rep" THEN "Sales Rep"
#            ELSE "Not Sales Rep"
#        END AS role
# FROM employees LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('Diane', 'Murphy', 'President', 'Not Sales Rep'),
#  ('Mary', 'Patterson', 'VP Sales', 'Not Sales Rep'),
#  ('Jeff', 'Firrelli', 'VP Marketing', 'Not Sales Rep'),
#  ('William', 'Patterson', 'Sales Manager (APAC)', 'Not Sales Rep'),
#  ('Gerard', 'Bondur', 'Sale Manager (EMEA)', 'Not Sales Rep')]

# %% [markdown]
# ## Shorter CASE Syntax
#
# If comparing one column repeatedly:

# %%
# %%sql
# SELECT firstName, lastName, officeCode,
#        CASE officeCode
#            WHEN "1" THEN "San Francisco, CA"
#            WHEN "2" THEN "Boston, MA"
#            WHEN "3" THEN "New York, NY"
#            WHEN "4" THEN "Paris, France"
#            WHEN "5" THEN "Tokyo, Japan"
#        END AS office
# FROM employees LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('Diane', 'Murphy', '1', 'San Francisco, CA'),
#  ('Mary', 'Patterson', '1', 'San Francisco, CA'),
#  ('Jeff', 'Firrelli', '1', 'San Francisco, CA'),
#  ('William', 'Patterson', '6', None),
#  ('Gerard', 'Bondur', '4', 'Paris, France')]

# %%
# %%sql
#
# SELECT productName,MSRP,quantityInStock,
#     CASE
#         WHEN MSRP < 100  THEN "low Stock"
#         ELSE "ok"
#     END AS stock_status
# FROM products
# LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('1969 Harley Davidson Ultimate Chopper', '95.70', '7933', 'ok'),
#  ('1952 Alpine Renault 1300', '214.30', '7305', 'ok'),
#  ('1996 Moto Guzzi 1100i', '118.94', '6625', 'ok'),
#  ('2003 Harley-Davidson Eagle Drag Bike', '193.66', '5582', 'ok'),
#  ('1972 Alfa Romeo GTA', '136.00', '3252', 'ok')]

# %%
# %%sql
# SELECT productName,
#        MSRP,
#        quantityInStock,
#        CASE
#            WHEN quantityInStock < 5000 THEN 'Low Stock'
#            WHEN quantityInStock > 6000 THEN 'High Stock'
#            ELSE 'Medium Stock'
#        END AS Stock_Status
# FROM products LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('1969 Harley Davidson Ultimate Chopper', '95.70', '7933', 'High Stock'),
#  ('1952 Alpine Renault 1300', '214.30', '7305', 'High Stock'),
#  ('1996 Moto Guzzi 1100i', '118.94', '6625', 'High Stock'),
#  ('2003 Harley-Davidson Eagle Drag Bike', '193.66', '5582', 'High Stock'),
#  ('1972 Alfa Romeo GTA', '136.00', '3252', 'High Stock')]

# %% [markdown]
# ##  Built-in SQL Functions
#
# SQL includes built-in functions for:
#
# - String manipulation
#
# - Mathematical operations
#
# - Date and time operations

# %% [markdown]
# ## String Functions
# `length()`
#
# Returns the number of characters in a string.

# %%
# %%sql
# SELECT firstName,length(firstName) AS name_length,length(lastName) AS length_name_2,
# FROM employees LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# (sqlite3.OperationalError) near "FROM": syntax error
# [SQL: SELECT firstName,length(firstName) AS name_length,length(lastName) AS length_name_2,
# FROM employees LIMIT 5;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# SELECT length(orderNumber) FROM orders LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [(5,), (5,), (5,), (5,), (5,)]

# %% [markdown]
# `upper()`
#
# Converts text to uppercase.

# %%
# %%sql
# SELECT upper(firstName) AS name_in_all_caps
# FROM employees LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('DIANE',), ('MARY',), ('JEFF',), ('WILLIAM',), ('GERARD',)]

# %%
# %%sql
# SELECT REPLACE(firstName,'a',"@@") AS new_name FROM employees LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('Di@@ne',), ('M@@ry',), ('Jeff',), ('Willi@@m',), ('Ger@@rd',)]

# %% [markdown]
# `substr()`
#
# Extracts part of a string.

# %%
# %%sql
# SELECT substr(firstName, 1, 1) || "." AS first_initial
# FROM employees LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('D.',), ('M.',), ('J.',), ('W.',), ('G.',)]

# %%
# %%sql
# SELECT SUBSTR(productName,5) AS name,SUBSTR(productName,1,4) AS modelYear FROM products LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [(' Harley Davidson Ultimate Chopper', '1969'),
#  (' Alpine Renault 1300', '1952'),
#  (' Moto Guzzi 1100i', '1996'),
#  (' Harley-Davidson Eagle Drag Bike', '2003'),
#  (' Alfa Romeo GTA', '1972')]

# %% [markdown]
# `Concatenation`
#
# Combine columns using ||

# %%
# %%sql
# SELECT * FROM employees LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('1002', 'Murphy', 'Diane', 'x5800', 'dmurphy@classicmodelcars.com', '1', '', 'President'),
#  ('1056', 'Patterson', 'Mary', 'x4611', 'mpatterso@classicmodelcars.com', '1', '1002', 'VP Sales'),
#  ('1076', 'Firrelli', 'Jeff', 'x9273', 'jfirrelli@classicmodelcars.com', '1', '1002', 'VP Marketing'),
#  ('1088', 'Patterson', 'William', 'x4871', 'wpatterson@classicmodelcars.com', '6', '1056', 'Sales Manager (APAC)'),
#  ('1102', 'Bondur', 'Gerard', 'x5408', 'gbondur@classicmodelcars.com', '4', '1056', 'Sale Manager (EMEA)')]

# %%
# %%sql
# SELECT firstName || " " || lastName ||"-"||employeeNumber AS full_name
# FROM employees LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('Diane Murphy-1002',),
#  ('Mary Patterson-1056',),
#  ('Jeff Firrelli-1076',),
#  ('William Patterson-1088',),
#  ('Gerard Bondur-1102',)]

# %% [markdown]
# ## Math Operations

# %%
# %%sql
# SELECT *
# FROM orderDetails LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('10100', 'S18_1749', '30', '136.00', '3'),
#  ('10100', 'S18_2248', '50', '55.09', '2'),
#  ('10100', 'S18_4409', '22', '75.46', '4'),
#  ('10100', 'S24_3969', '49', '35.29', '1'),
#  ('10101', 'S18_2325', '25', '108.06', '4')]

# %% [markdown]
# `round()`

# %%
# %%sql
# SELECT round(priceEach) AS rounded_price
# FROM orderDetails LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [(136.0,), (55.0,), (75.0,), (35.0,), (108.0,)]

# %%
# %%sql
# SELECT priceEach,ROUND(priceEach,1) FROM orderDetails LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('136.00', 136.0),
#  ('55.09', 55.1),
#  ('75.46', 75.5),
#  ('35.29', 35.3),
#  ('108.06', 108.1)]

# %% [markdown]
# `CAST()`
#
# Convert data type.

# %%
# %%sql
# SELECT CAST(round(priceEach) AS INTEGER) AS rounded_price_int
# FROM orderDetails LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [(136,), (55,), (75,), (35,), (108,)]

# %%
# %%sql
# SELECT SUBSTR(CAST(priceEach AS INTEGER),"0") FROM orderDetails LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('136',), ('55',), ('75',), ('35',), ('108',)]

# %% [markdown]
# `Basic Math Operators`

# %%
# %%sql
# SELECT priceEach * quantityOrdered AS total_price
# FROM orderDetails LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [(4080.0,), (2754.5,), (1660.12,), (1729.21,), (2701.5,)]

# %%
# %%sql
# SELECT * FROM products LIMIT 1
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('S10_1678', '1969 Harley Davidson Ultimate Chopper', 'Motorcycles', '1:10', 'Min Lin Diecast', 'This replica features working kickstand, front suspension, gear-shift lever, footbrake lever, drive chain, wheels and steering. All parts are particularly delicate due to their precise scale and require special care and attention.', '7933', '48.81', '95.70')]

# %%
# %%sql
# SELECT productDescription,buyPrice,productDescription * buyPrice AS new_col FROM products LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('This replica features working kickstand, front suspension, gear-shift lever, footbrake lever, drive chain, wheels and steering. All parts are particularly delicate due to their precise scale and require special care and attention.', '48.81', 0.0),
#  ('Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.', '98.58', 0.0),
#  ('Official Moto Guzzi logos and insignias, saddle bags located on side of motorcycle, detailed engine, working steering, working suspension, two leathe ... (93 characters truncated) ... paint with chrome accents, superior die-cast detail , rotating wheels , working kick stand, diecast metal with plastic parts and baked enamel finish.', '68.99', 0.0),
# ...

# %%
1969 * 48.81
# Out:
# 96106.89

# %% [markdown]
# ## Date and Time Functions

# %%
# %%sql
# SELECT * FROM orders LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('10100', '2003-01-06', '2003-01-13', '2003-01-10', 'Shipped', '', '363'),
#  ('10101', '2003-01-09', '2003-01-18', '2003-01-11', 'Shipped', 'Check on availability.', '128'),
#  ('10102', '2003-01-10', '2003-01-18', '2003-01-14', 'Shipped', '', '181'),
#  ('10103', '2003-01-29', '2003-02-07', '2003-02-02', 'Shipped', '', '121'),
#  ('10104', '2003-01-31', '2003-02-09', '2003-02-01', 'Shipped', '', '141')]

# %% [markdown]
# ```python
# %%sql
# SELECT requiredDate - orderDate
# FROM orders;
# ```

# %%
# %%sql
# SELECT shippedDate,orderDate,shippedDate - orderDate as days_to_ship from orders LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('2003-01-10', '2003-01-06', 0),
#  ('2003-01-11', '2003-01-09', 0),
#  ('2003-01-14', '2003-01-10', 0),
#  ('2003-02-02', '2003-01-29', 0),
#  ('2003-02-01', '2003-01-31', 0)]

# %% [markdown]
# `Calculating Date Differences`
#
# Direct subtraction does not work:

# %% [markdown]
# ```sql
# %%sql
# SELECT julianday(requiredDate) - julianday(orderDate)
#        AS days_from_order_to_required
# FROM orders;
# ```

# %%
# %%sql
# SELECT requiredDate,orderDate,julianday(requiredDate) - julianday(orderDate)
#        AS days_from_order_to_required
# FROM orders LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('2003-01-13', '2003-01-06', 7.0),
#  ('2003-01-18', '2003-01-09', 9.0),
#  ('2003-01-18', '2003-01-10', 8.0),
#  ('2003-02-07', '2003-01-29', 9.0),
#  ('2003-02-09', '2003-01-31', 9.0)]

# %% [markdown]
# ## Introduction to the WHERE Clause
#
# The WHERE clause filters rows based on a condition.
#
# The simplest condition checks whether a column equals a specific value using =.

# %%
# %%sql
# SELECT *
# FROM employees
# WHERE lastName = "Patterson" LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('1056', 'Patterson', 'Mary', 'x4611', 'mpatterso@classicmodelcars.com', '1', '1002', 'VP Sales'),
#  ('1088', 'Patterson', 'William', 'x4871', 'wpatterson@classicmodelcars.com', '6', '1056', 'Sales Manager (APAC)'),
#  ('1216', 'Patterson', 'Steve', 'x4334', 'spatterson@classicmodelcars.com', '2', '1143', 'Sales Rep')]

# %% [markdown]
# This returns all columns, but only rows where lastName is "Patterson".

# %%
# %%sql
# SELECT * FROM orders WHERE  NOT status="Shipped" LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('10164', '2003-10-21', '2003-10-30', '2003-10-23', 'Resolved', "This order was disputed, but resolved on 11/1/2003; Customer doesn't like the colors and precision of the models.", '452'),
#  ('10167', '2003-10-23', '2003-10-30', '', 'Cancelled', "Customer called to cancel. The warehouse was notified in time and the order didn't ship. They have a new VP of Sales and are shifting their sales model. Our VP of Sales should contact them.", '448'),
#  ('10179', '2003-11-11', '2003-11-17', '2003-11-13', 'Cancelled', 'Customer cancelled due to urgent budgeting issues. Must be cautious when dealing with them in the future. Since order shipped already we must discuss who would cover the shipping charges.', '496'),
#  ('10248', '2004-05-07', '2004-05-14', '', 'Cancelled', 'Order was mistakenly placed. The warehouse noticed the lack of documentation.', '131'),
# ...

# %% [markdown]
# ## Filtering Columns and Rows Together

# %%
# %%sql
# SELECT firstName, lastName, email
# FROM employees
# WHERE lastName = "Patterson" LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('Mary', 'Patterson', 'mpatterso@classicmodelcars.com'),
#  ('William', 'Patterson', 'wpatterson@classicmodelcars.com'),
#  ('Steve', 'Patterson', 'spatterson@classicmodelcars.com')]

# %% [markdown]
# This filters both:
#
# Columns (firstName, lastName, email)
#
# Rows (only Patterson records)

# %% [markdown]
# # Common Conditional Operators in SQL
#
# | Operator   | Meaning                         | Example Usage |
# |------------|----------------------------------|---------------|
# | `!=`       | Not equal to                     | `age != 18` |
# | `>`        | Greater than                     | `age > 30` |
# | `>=`       | Greater than or equal to         | `age >= 21` |
# | `<`        | Less than                        | `age < 50` |
# | `<=`       | Less than or equal to            | `age <= 100` |
# | `AND`      | Both conditions must be true     | `age > 18 AND age < 30` |
# | `OR`       | At least one condition is true   | `breed = "Tabby" OR breed = "Calico"` |
# | `BETWEEN`  | Value within a range (inclusive) | `age BETWEEN 2 AND 5` |
# | `IN`       | Match any value in a list        | `breed IN ("Tabby", "Calico")` |
# | `LIKE`     | Pattern matching (text search)   | `name LIKE "M%"` |

# %% [markdown]
# # Common Conditional Operators in SQL
#
# # 1. `!=` (Not Equal To)
#
# Get customers not from USA:
#
# ```sql
# SELECT customerName, country
# FROM customers
# WHERE country != "USA";
# ``

# %%
# %%sql
# SELECT customerName, country
# FROM customers
# WHERE country != "USA";
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('Atelier graphique', 'France'),
#  ('Australian Collectors, Co.', 'Australia'),
#  ('La Rochelle Gifts', 'France'),
#  ('Baane Mini Imports', 'Norway'),
#  ('Havel & Zbyszek Co', 'Poland'),
#  ('Blauer See Auto, Co.', 'Germany'),
#  ('Euro+ Shopping Channel', 'Spain'),
#  ('Volvo Model Replicas, Co', 'Sweden'),
#  ('Danish Wholesale Imports', 'Denmark'),
#  ('Saveley & Henriot, Co.', 'France'),
#  ('Dragon Souveniers, Ltd.', 'Singapore'),
#  ('Handji Gifts& Co', 'Singapore'),
#  ('Herkku Gifts', 'Norway  '),
#  ('Porto Imports Co.', 'Portugal'),
#  ('Daedalus Designs Imports', 'France'),
#  ("La Corne D'abondance, Co.", 'France'),
#  ('Osaka Souveniers Co.', 'Japan'),
#  ('Toys of Finland, Co.', 'Finland'),
#  ('AV Stores, Co.', 'UK'),
#  ('Clover Collections, Co.', 'Ireland'),
#  ('UK Collectables, Ltd.', 'UK'),
#  ('Canadian Gift Exchange Network', 'Canada'),
#  ('Asian Shopping Network, Co', 'Singapore'),
#  ('Mini Caravy', 'France'),
# ...

# %% [markdown]
# # 2. `>` (Greater Than)
#
# Get payments greater than 50,000:
#
# ```sql
# SELECT customerNumber, amount
# FROM payments
# WHERE amount > 50000;
# ```

# %%
# %%sql
# SELECT customerNumber, amount
# FROM payments
# WHERE amount > 50000;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('103', '6066.78'),
#  ('103', '14571.44'),
#  ('103', '1676.14'),
#  ('112', '14191.12'),
#  ('112', '32641.98'),
#  ('112', '33347.88'),
#  ('114', '45864.03'),
#  ('114', '82261.22'),
#  ('114', '7565.08'),
#  ('114', '44894.74'),
#  ('119', '19501.82'),
#  ('119', '47924.19'),
#  ('119', '49523.67'),
#  ('121', '50218.95'),
#  ('121', '1491.38'),
#  ('121', '17876.32'),
#  ('121', '34638.14'),
#  ('124', '101244.59'),
#  ('124', '85410.87'),
#  ('124', '11044.30'),
#  ('124', '83598.04'),
#  ('124', '47142.70'),
#  ('124', '55639.66'),
#  ('124', '111654.40'),
#  ('124', '43369.30'),
#  ('124', '45084.38'),
#  ('128', '10549.01'),
#  ('128', '24101.81'),
#  ('128', '33820.62'),
#  ('128', '7466.32'),
#  ('129', '26248.78'),
#  ('129', '23923.93'),
#  ('129', '16537.85'),
#  ('131', '22292.62'),
#  ('131', '50025.35'),
#  ('131', '35321.97'),
#  ('141', '36251.03'),
#  ('141', '36140.38'),
#  ('141', '46895.48'),
#  ('141', '59830.55'),
# ...

# %% [markdown]
# # 3. `>=` (Greater Than or Equal To)
#
# Get products with MSRP 100 or more:
#
# ```sql
# SELECT productName, MSRP
# FROM products
# WHERE MSRP >= 100;
# ```

# %%
# %%sql
# SELECT productName, MSRP
# FROM products
# WHERE MSRP >= 100;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('1969 Harley Davidson Ultimate Chopper', '95.70'),
#  ('1952 Alpine Renault 1300', '214.30'),
#  ('1996 Moto Guzzi 1100i', '118.94'),
#  ('2003 Harley-Davidson Eagle Drag Bike', '193.66'),
#  ('1972 Alfa Romeo GTA', '136.00'),
#  ('1962 LanciaA Delta 16V', '147.74'),
#  ('1968 Ford Mustang', '194.57'),
#  ('2001 Ferrari Enzo', '207.80'),
#  ('1958 Setra Bus', '136.67'),
#  ('2002 Suzuki XREO', '150.62'),
#  ('1969 Corvair Monza', '151.08'),
#  ('1968 Dodge Charger', '117.44'),
#  ('1969 Ford Falcon', '173.02'),
#  ('1970 Plymouth Hemi Cuda', '79.80'),
#  ('1957 Chevy Pickup', '118.50'),
#  ('1969 Dodge Charger', '115.16'),
#  ('1940 Ford Pickup Truck', '116.67'),
#  ('1993 Mazda RX-7', '141.54'),
#  ('1937 Lincoln Berline', '102.74'),
#  ('1936 Mercedes-Benz 500K Special Roadster', '53.91'),
#  ('1965 Aston Martin DB5', '124.44'),
#  ('1980s Black Hawk Helicopter', '157.69'),
#  ('1917 Grand Touring Sedan', '170.00'),
# ...

# %% [markdown]
# # 4. `<` (Less Than)
#
# Get products with quantity in stock less than 1000:
#
# ```sql
# SELECT productName, quantityInStock
# FROM products
# WHERE quantityInStock < 1000;
# ```

# %%
# %%sql
# SELECT productName, quantityInStock
# FROM products
# WHERE quantityInStock < 1000;
# Out:
#  * sqlite:///data.sqlite
# Done.
# []

# %% [markdown]
# # 5. `<=` (Less Than or Equal To)
#
# Get customers with credit limit less than or equal to 50,000:
#
# ```sql
# SELECT customerName, creditLimit
# FROM customers
# WHERE creditLimit <= 50000;
# ```

# %%
# %%sql
# SELECT customerName, creditLimit
# FROM customers
# WHERE creditLimit <= 50000;
# Out:
#  * sqlite:///data.sqlite
# Done.
# []

# %% [markdown]
# # 6. `AND` (Both Conditions Must Be True)
#
# Get customers from USA with credit limit above 100,000:
#
# ```sql
# SELECT customerName, country, creditLimit
# FROM customers
# WHERE country = "USA"
# AND creditLimit > 100000;
# ```
#
# Both conditions must be true.

# %%
# %%sql
# SELECT customerName, country, creditLimit
# FROM customers
# WHERE country = "USA"
# AND creditLimit > 100000;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('Signal Gift Stores', 'USA', '71800.00'),
#  ('Mini Gifts Distributors Ltd.', 'USA', '210500.00'),
#  ('Mini Wheels Co.', 'USA', '64600.00'),
#  ('Land of Toys Inc.', 'USA', '114900.00'),
#  ('Muscle Machine Inc', 'USA', '138500.00'),
#  ('Diecast Classics Inc.', 'USA', '100600.00'),
#  ('Technics Stores Inc.', 'USA', '84600.00'),
#  ('American Souvenirs Inc', 'USA', '0.00'),
#  ('Cambridge Collectables Co.', 'USA', '43400.00'),
#  ('Gift Depot Inc.', 'USA', '84300.00'),
#  ('Vitachrome Inc.', 'USA', '76400.00'),
#  ('Auto-Moto Classics Inc.', 'USA', '23000.00'),
#  ('Online Mini Collectables', 'USA', '68700.00'),
#  ('Toys4GrownUps.com', 'USA', '90700.00'),
#  ('Boards & Toys Co.', 'USA', '11000.00'),
#  ('Collectable Mini Designs Co.', 'USA', '105000.00'),
#  ("Marta's Replicas Co.", 'USA', '123700.00'),
#  ('Mini Classics', 'USA', '102700.00'),
#  ('Mini Creations Ltd.', 'USA', '94500.00'),
#  ('Corporate Gift Ideas Co.', 'USA', '105000.00'),
# ...

# %% [markdown]
# # 7. `OR` (At Least One Condition Must Be True)
#
# Get customers from France or Germany:
#
# ```sql
# SELECT customerName, country
# FROM customers
# WHERE country = "France"
# OR country = "Germany";
# ```

# %%
# %%sql
# SELECT customerName, country
# FROM customers
# WHERE country = "France"
# OR country = "Germany";
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('Atelier graphique', 'France'),
#  ('La Rochelle Gifts', 'France'),
#  ('Blauer See Auto, Co.', 'Germany'),
#  ('Saveley & Henriot, Co.', 'France'),
#  ('Daedalus Designs Imports', 'France'),
#  ("La Corne D'abondance, Co.", 'France'),
#  ('Mini Caravy', 'France'),
#  ('Natürlich Autos', 'Germany'),
#  ('Alpha Cognac', 'France'),
#  ('Messner Shopping Network', 'Germany'),
#  ('Lyon Souveniers', 'France'),
#  ('Auto Associés & Cie.', 'France'),
#  ('Toms Spezialitäten, Ltd', 'Germany'),
#  ('Franken Gifts, Co', 'Germany'),
#  ('Der Hund Imports', 'Germany'),
#  ('Cramer Spezialitäten, Ltd', 'Germany'),
#  ('Marseille Mini Autos', 'France'),
#  ('Reims Collectables', 'France'),
#  ('Kommission Auto', 'Germany'),
#  ('Auto Canal+ Petit', 'France'),
#  ('Stuttgart Collectable Exchange', 'Germany'),
#  ('Bavarian Collectables Imports, Co.', 'Germany'),
#  ('Feuer Online Stores, Inc', 'Germany'),
#  ('Warburg Exchange', 'Germany'),
# ...

# %% [markdown]
# # 8. `BETWEEN` (Inclusive Range)
#
# Get payments between 10,000 and 50,000:
#
# ```sql
# SELECT customerNumber, amount
# FROM payments
# WHERE amount BETWEEN 10000 AND 50000;
# ```
#
# Equivalent to:
#
# ```sql
# WHERE amount >= 10000 AND amount <= 50000;
# ```

# %%
# %%sql
# SELECT customerNumber, amount
# FROM payments
# WHERE amount BETWEEN 10000 AND 50000;
# Out:
#  * sqlite:///data.sqlite
# Done.
# []

# %% [markdown]
# # 9. `IN` (Match from a List)
#
# Get orders with specific statuses:
#
# ```sql
# SELECT orderNumber, status
# FROM orders
# WHERE status IN ("Shipped", "Resolved");
# ```
#
# Equivalent to:
#
# ```sql
# WHERE status = "Shipped"
# OR status = "Resolved";
# ```

# %%
# %%sql
# SELECT orderNumber, status
# FROM orders
# WHERE status IN ("Shipped", "Resolved") LIMIT 5;
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('10100', 'Shipped'),
#  ('10101', 'Shipped'),
#  ('10102', 'Shipped'),
#  ('10103', 'Shipped'),
#  ('10104', 'Shipped')]

# %% [markdown]
# # 10. `LIKE` (Pattern Matching)
#
# Customers whose name starts with "A":
#
# ```sql
# SELECT customerName
# FROM customers
# WHERE customerName LIKE "A%";
# ```
#
# Products containing the word "Ford":
#
# ```sql
# SELECT productName
# FROM products
# WHERE productName LIKE "%Ford%";
# ```

# %%
# %%sql
# SELECT productName
# FROM products
# WHERE productName LIKE "%Ford%" LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('1968 Ford Mustang',),
#  ('1969 Ford Falcon',),
#  ('1940 Ford Pickup Truck',),
#  ('1911 Ford Town Car',),
#  ('1932 Model A Ford J-Coupe',)]

# %% [markdown]
# # Combining Multiple Operators
#
# Get shipped orders from 2004:
#
# ```sql
# SELECT orderNumber, orderDate, status
# FROM orders
# WHERE status = "Shipped"
# AND strftime('%Y', orderDate) = '2004';
# ```
#
# Customers from USA with credit limit between 50,000 and 150,000:
#
# ```sql
# SELECT customerName, creditLimit
# FROM customers
# WHERE country = "USA"
# AND creditLimit BETWEEN 50000 AND 150000;
# ```

# %%
# %%sql
# SELECT orderNumber, orderDate, status
# FROM orders
# WHERE status = "Shipped"
# AND strftime('%Y', orderDate) = '2004'
# LIMIT 5
# Out:
#  * sqlite:///data.sqlite
# Done.
# [('10208', '2004-01-02', 'Shipped'),
#  ('10209', '2004-01-09', 'Shipped'),
#  ('10210', '2004-01-12', 'Shipped'),
#  ('10211', '2004-01-15', 'Shipped'),
#  ('10212', '2004-01-16', 'Shipped')]
